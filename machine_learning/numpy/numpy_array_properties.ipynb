# %%
import numpy as np

# %%
arr_2d = np.array([[1,2,3],
                   [4,5,6]])
print(arr_2d.shape)
print(arr_2d.size)
print(arr_2d.ndim)
print(arr_2d.dtype)
chenge_datatype = arr_2d.astype(float)
print(chenge_datatype.dtype)
# Out:
# (2, 3)
# 6
# 2
# int64
# float64
