# %%
import numpy as np
print(np.__version__)
# Out:
# 2.4.4

# %%
A = np.array([[4,3,-5],
             [-2,-4,5],
             [0,8,8]])
B = np.array([2,5,-3])

# %%
X = np.linalg.solve(A,B)
print("x =",X[0])
print("y =",X[1])
print("z =",X[2])
# Out:
# x = 2.80625
# y = -1.3875
# z = 1.0125
