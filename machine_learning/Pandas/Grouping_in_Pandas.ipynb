# %% [markdown]
# <a href="https://colab.research.google.com/github/student-sayan/Machine_Learning/blob/main/machine_learning/Pandas/Grouping_in_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    "Name" : ["Ram","Shyam","Ghanshyam","Dhanshyam","Aditi","Jagdish","Raj","Simran"],
    "Age" : [22,34,22,40,29,40,25,29],
    "Salary" : [50000,60000,45000,52000,49000,70000,48000,58000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#         Name  Age  Salary
# 0        Ram   22   50000
# 1      Shyam   34   60000
# 2  Ghanshyam   22   45000
# 3  Dhanshyam   40   52000
# 4      Aditi   29   49000
# 5    Jagdish   40   70000
# 6        Raj   25   48000
# 7     Simran   29   58000

# %%
group1 = df.groupby("Age")["Salary"].sum()
print(group1)
# Out:
# Age
# 22     95000
# 25     48000
# 29    107000
# 34     60000
# 40    122000
# Name: Salary, dtype: int64

# %%
group2 = df.groupby(["Age","Name"])["Salary"].sum()
print(group2)
# Out:
# Age  Name
# 22   Ghanshyam    45000
#      Ram          50000
# 25   Raj          48000
# 29   Aditi        49000
#      Simran       58000
# 34   Shyam        60000
# 40   Dhanshyam    52000
#      Jagdish      70000
# Name: Salary, dtype: int64
