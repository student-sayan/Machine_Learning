# %% [markdown]
# <a href="https://colab.research.google.com/github/student-sayan/Machine_Learning/blob/main/machine_learning/Pandas/data_set_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    "Name" : ["Ram","Shyam","Ghanshyam","Dhanshyam","Aditi","Jagdish","Raj","Simran"],
    "Age" : [28,34,22,30,29,40,25,32],
    "Salary" : [50000,60000,45000,52000,49000,70000,48000,58000],
    "Performance Score" : [85,90,78,92,88,95,80,89]
}

df = pd.DataFrame(data)
print(df)
# Out:
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Salary', 'Performance Score'], dtype='object')

# %%
df.to_csv("Demo2.csv",index=False)
df.to_excel("Demo2.xlsx",index=False)
df.to_json("Demo2.json",index=False)

# %%
s = df[(df["Age"]>=30) & (df["Salary"]>52000)]
print(s)
# Out:
#       Name  Age  Salary  Performance Score
# 1    Shyam   34   60000                 90
# 5  Jagdish   40   70000                 95
# 7   Simran   32   58000                 89

# %%
print(df[["Name","Age"]])
# Out:
#         Name  Age
# 0        Ram   28
# 1      Shyam   34
# 2  Ghanshyam   22
# 3  Dhanshyam   30
# 4      Aditi   29
# 5    Jagdish   40
# 6        Raj   25
# 7     Simran   32
